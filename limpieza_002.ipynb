# %%
import pandas as pd

# %%
data = pd.read_csv("ods_1_2_definitivo.csv")

# %%
data.keys()
# Out:
# Index(['id_str', 'from_user', 'created_at', 'time', 'geo_coordinates',
#        'user_lang', 'in_reply_to_user_id_str', 'in_reply_to_screen_name',
#        'from_user_id_str', 'in_reply_to_status_id_str', 'profile_image_url',
#        'user_followers_count', 'user_friends_count', 'user_location',
#        'status_url', 'entities_str', 'textoNew', 'SourceNew'],
#       dtype='object')

# %%
gru = data.groupby(["from_user_id_str"])['from_user']

# %%
for nombre, datos in gru:
    if(len(list(datos))>1):
        # print(nombre)
        if(len(list(set(list(datos))))>1):
            print(list(datos), nombre)
# Out:
# [5489.0, 5490.0, 5488.0] 4478211
# [366.0, 366.0, 365.0, 364.0, 364.0, 364.0] 6129822
# [6065.0, 6058.0, 6055.0] 8087392
# [513.0, 508.0] 8932752
# [5203.0, 5202.0] 9685592
# [11878.0, 11873.0, 11875.0] 9973482
# [316.0, 313.0] 10014532
# [40196.0, 40197.0, 40210.0, 40210.0, 40227.0] 11248882
# [8172.0, 8173.0] 14509172
# [5917.0, 5913.0, 5902.0, 5889.0] 14573832
# [1204.0, 1200.0] 14661878
# [1309.0, 1301.0] 14698820
# [3149.0, 3150.0, 3150.0, 3141.0, 3141.0, 3139.0, 3139.0, 3133.0, 3125.0, 3126.0, 3126.0, 3126.0, 3123.0, 3125.0, 3124.0] 14704665
# [60956.0, 60922.0] 14786159
# [1046.0, 1040.0, 1038.0] 14804670
# [817.0, 817.0, 816.0] 14838117
# [1649.0, 1644.0] 14954610
# [2395.0, 2392.0] 14968044
# [104036.0, 103994.0, 103951.0, 103894.0, 103864.0] 15468474
# [114279.0, 114041.0] 15544077
# [5199.0, 5195.0] 15807954
# [74832.0, 74772.0] 15901999
# [7694.0, 7711.0, 7711.0] 16025497
# [10371.0, 10371.0, 10376.0, 10374.0, 10374.0, 10367.0, 10366.0, 10357.0] 16109701
# ...

# %%
data.loc[(data['from_user_id_str'] == 65929720), 'from_user'] = 'marbrandd'

# %%
data[data['from_user_id_str'] == 65929720]
# Out:
#                    id_str  from_user                      created_at  \
# 1121  1143859474677030913  marbrandd  Wed Jun 26 12:32:05 +0000 2019
# 4516  1141713767920734208  marbrandd  Thu Jun 20 14:25:48 +0000 2019
#
#                      time     geo_coordinates user_lang  \
# 1121  26/06/2019 13:32:05  loc: 00.000,00.000        es
# 4516  20/06/2019 15:25:48  loc: 00.000,00.000        en
#
#       in_reply_to_user_id_str in_reply_to_screen_name  from_user_id_str  \
# 1121                      0.0                       -          65929720
# 4516                      0.0                       -          65929720
#
#       in_reply_to_status_id_str  \
# 1121                        0.0
# 4516                        0.0
#
#                                       profile_image_url  user_followers_count  \
# 1121  http://pbs.twimg.com/profile_images/1010520817...                 751.0
# 4516  http://pbs.twimg.com/profile_images/1010520817...                 748.0
#
# ...

# %%
data.loc[(data['from_user_id_str'] == 16808626), 'from_user'] = 'bbva'

# %%
data[data['from_user_id_str'] == 16808626]
# Out:
#                     id_str from_user                      created_at  \
# 2679   1143118882632343552      bbva  Mon Jun 24 11:29:14 +0000 2019
# 3099   1142513589103812611      bbva  Sat Jun 22 19:24:01 +0000 2019
# 4166   1141813801626611712      bbva  Thu Jun 20 21:03:18 +0000 2019
# 4733   1141637461036216320      bbva  Thu Jun 20 09:22:35 +0000 2019
# 4744   1141635579362336768      bbva  Thu Jun 20 09:15:07 +0000 2019
# 8585   1139282313240612872      bbva  Thu Jun 13 21:24:04 +0000 2019
# 13972  1136566971938541569      bbva  Thu Jun 06 09:34:17 +0000 2019
# 16985  1135522523087548417      bbva  Mon Jun 03 12:24:01 +0000 2019
# 17766  1134891365429579777      bbva  Sat Jun 01 18:36:01 +0000 2019
#
#                       time     geo_coordinates user_lang  \
# 2679   24/06/2019 12:29:14  loc: 00.000,00.000        es
# 3099   22/06/2019 20:24:01  loc: 00.000,00.000        es
# 4166   20/06/2019 22:03:18  loc: 00.000,00.000        es
# ...

# %%
data.loc[(data['from_user_id_str'] == 230125016), 'from_user'] = 'BBVAWorld'

# %%
data[data['from_user_id_str'] == 230125016]
# Out:
#                     id_str  from_user                      created_at  \
# 4350   1141753733849714688  BBVAWorld  Thu Jun 20 17:04:37 +0000 2019
# 4708   1141645626930806786  BBVAWorld  Thu Jun 20 09:55:02 +0000 2019
# 11734  1137500558141677568  BBVAWorld  Sat Jun 08 23:24:01 +0000 2019
# 13547  1136657155971518464  BBVAWorld  Thu Jun 06 15:32:38 +0000 2019
#
#                       time     geo_coordinates user_lang  \
# 4350   20/06/2019 18:04:37  loc: 00.000,00.000        es
# 4708   20/06/2019 10:55:02  loc: 00.000,00.000        es
# 11734  09/06/2019 00:24:01  loc: 00.000,00.000        es
# 13547  06/06/2019 16:32:38  loc: 00.000,00.000        es
#
#        in_reply_to_user_id_str in_reply_to_screen_name  from_user_id_str  \
# 4350                       0.0                       -         230125016
# 4708                       0.0                       -         230125016
# 11734                      0.0                       -         230125016
# ...

# %%
data.loc[(data['from_user_id_str'] == 271387915), 'from_user'] = 'CarolAlvarezmb'

# %%
data[data['from_user_id_str'] == 271387915]
# Out:
#                     id_str       from_user                      created_at  \
# 2568   1143167223340683264  CarolAlvarezmb  Mon Jun 24 14:41:19 +0000 2019
# 2614   1143152143710511104  CarolAlvarezmb  Mon Jun 24 13:41:24 +0000 2019
# 2785   1143055652035710977  CarolAlvarezmb  Mon Jun 24 07:17:59 +0000 2019
# 4534   1141709472693440512  CarolAlvarezmb  Thu Jun 20 14:08:44 +0000 2019
# 5666   1141277017767391233  CarolAlvarezmb  Wed Jun 19 09:30:19 +0000 2019
# 6530   1140928357246353410  CarolAlvarezmb  Tue Jun 18 10:24:52 +0000 2019
# 6571   1140910474218917889  CarolAlvarezmb  Tue Jun 18 09:13:48 +0000 2019
# 7229   1140557950160986113  CarolAlvarezmb  Mon Jun 17 09:53:00 +0000 2019
# 9171   1139098392318095361  CarolAlvarezmb  Thu Jun 13 09:13:14 +0000 2019
# 10569  1138481688487636992  CarolAlvarezmb  Tue Jun 11 16:22:41 +0000 2019
# 10576  1138478849963036672  CarolAlvarezmb  Tue Jun 11 16:11:24 +0000 2019
# ...

# %%
data.loc[(data['from_user_id_str'] == 1138828392025993216), 'from_user'] = 'SilviaCFerreyra'

# %%
data[data['from_user_id_str'] == 1138828392025993216]
# Out:
#                    id_str        from_user                      created_at  \
# 7445  1140263981208285184  SilviaCFerreyra  Sun Jun 16 14:24:52 +0000 2019
# 7596  1140006628651089922  SilviaCFerreyra  Sat Jun 15 21:22:15 +0000 2019
# 9731  1138831299551092736  SilviaCFerreyra  Wed Jun 12 15:31:54 +0000 2019
#
#                      time     geo_coordinates user_lang  \
# 7445  16/06/2019 15:24:52  loc: 00.000,00.000        es
# 7596  15/06/2019 22:22:15  loc: 00.000,00.000        es
# 9731  12/06/2019 16:31:54  loc: 00.000,00.000        en
#
#       in_reply_to_user_id_str in_reply_to_screen_name     from_user_id_str  \
# 7445                      0.0                       -  1138828392025993216
# 7596                      0.0                       -  1138828392025993216
# 9731                      0.0                       -  1138828392025993216
#
#       in_reply_to_status_id_str  \
# 7445                        0.0
# 7596                        0.0
# ...

# %%
data.to_csv("ods_1_2_definitivo.csv", index=False)
