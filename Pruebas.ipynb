# %%
import pandas as pd

# %%
data = pd.read_csv("data/ods_1_2.csv", sep =',', encoding = "utf-8")

# %%
data['source']
# Out:
# 0        <a href="https://about.twitter.com/products/tw...
# 1        <a href="http://twitter.com/download/iphone" r...
# 2        <a href="http://twitter.com/download/android" ...
# 3        <a href="http://twitter.com/download/android" ...
# 4        <a href="http://twitter.com/download/android" ...
#                                ...
# 18496    <a href="https://mobile.twitter.com" rel="nofo...
# 18497    <a href="http://twitter.com/download/android" ...
# 18498    <a href="http://twitter.com/download/android" ...
# 18499    <a href="http://twitter.com/download/android" ...
# 18500    <a href="http://twitter.com/download/android" ...
# Name: source, Length: 18501, dtype: object

# %%
print(data.source.isnull().sum())
# Out:
# 1

# %%
print(data.source.isnull())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18496    False
# 18497    False
# 18498    False
# 18499    False
# 18500    False
# Name: source, Length: 18501, dtype: bool

# %%
print(data.source.isnull() == True)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18496    False
# 18497    False
# 18498    False
# 18499    False
# 18500    False
# Name: source, Length: 18501, dtype: bool

# %%
print(data.source.isnull()) == True
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18496    False
# 18497    False
# 18498    False
# 18499    False
# 18500    False
# Name: source, Length: 18501, dtype: bool
# False

# %%
data.loc[(data.time == NaN),'source']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0f4e0eb3dfc2> in <module>
# ----> 1 data.loc[(data.time == NaN),'source']
#
# NameError: name 'NaN' is not defined

# %%
    data.loc[(data.in_reply_to_user_id_str == '-'),'in_reply_to_user_id_str'] = 0

# %%
data
# Out:
#                     id_str        from_user  \
# 0      1144191403557347329       osalanEJGV
# 1      1144190858163576832       CEAinforma
# 2      1144190759597498369  Plataforma3sect
# 3      1144190694053036032  Plataforma3sect
# 4      1144190578554540034      CesarNandis
# ...                    ...              ...
# 18496  1134819048028495872        quiroz979
# 18497  1134819030307680256       gramontani
# 18498  1134818548902236160  MatiasL14340413
# 18499  1134818540912091136       gramontani
# 18500  1134818135918469120  MatiasL14340413
#
#                                                     text  \
# 0      RT @LoliRicoG: Durante #Prevencia2019 tuve el ...
# 1      RT @Adolfo_Borrero: Javier González De Lara, P...
# 2      RT @Mesa3sectorAst: Los #ODS son una iniciativ...
# 3      RT @Mesa3sectorAst: Con la marcación de la cas...
# 4      RT @Agenda2030MX: Los 17 #ODS de la #Agenda203...
# ...                                                  ...
# ...

# %%
data
# Out:
#                     id_str        from_user                      created_at  \
# 0      1144191403557347329       osalanEJGV  Thu Jun 27 10:31:03 +0000 2019
# 1      1144190858163576832       CEAinforma  Thu Jun 27 10:28:53 +0000 2019
# 2      1144190759597498369  Plataforma3sect  Thu Jun 27 10:28:29 +0000 2019
# 3      1144190694053036032  Plataforma3sect  Thu Jun 27 10:28:14 +0000 2019
# 4      1144190578554540034      CesarNandis  Thu Jun 27 10:27:46 +0000 2019
# ...                    ...              ...                             ...
# 18494  1134819048028495872        quiroz979  Sat Jun 01 13:48:39 +0000 2019
# 18495  1134819030307680256       gramontani  Sat Jun 01 13:48:35 +0000 2019
# 18496  1134818548902236160  MatiasL14340413  Sat Jun 01 13:46:40 +0000 2019
# 18497  1134818540912091136       gramontani  Sat Jun 01 13:46:38 +0000 2019
# 18498  1134818135918469120  MatiasL14340413  Sat Jun 01 13:45:02 +0000 2019
#
# ...
